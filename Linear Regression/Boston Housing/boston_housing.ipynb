# %% [markdown]
# # Boston Housing Dataset :

# %% [markdown]
# The Boston housing data by Harrison and Rubinfeld (1979) and explore which factors affect the median value of homes.
#
# #### About the Data variables:
# Features :
# * crim - per capita crime rate by town.
# * zn - proportion of residential land zoned for lots over 25,000 sq.ft
# * indus - proportion of non-retail business acres per town
# * chas - Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# * nox - nitric oxides concentration (parts per 10 million)
# * rm - average number of rooms per dwelling
# * age - proportion of owner-occupied units built prior to 1940
# * dis - weighted distances to five Boston employment centres
# * rad - index of accessibility to radial highways
# * tax - full-value property-tax rate per USD 10,000
# * ptratio - pupil-teacher ratio by town
# * black - proportion of blacks by town
# * lstat - percentage of lower status of the population
#
# Target (dependent) :
# * medv - median value of owner-occupied homes in USD 1000’s

# %% [markdown]
# ## 1 . Loading the data :

# %%
import pandas as pd

# %%
df  = pd.read_csv("BostonHousing.csv")

# %% [markdown]
# ## 2. Data preprocessing :

# %% [markdown]
# ### Pandas Head :
# * This function returns the first 5 rows from the Dataframe.

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ### Pandas Tail :
# * This function returns last 5 rows from Dataframe.

# %%
df.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#       black  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %% [markdown]
# ### Pandas Shape :
# * Returns tuple of shape (Rows, columns) of Dataframe.

# %%
df.shape
# Out:
# (506, 14)

# %% [markdown]
# * This dataset contains 506 rows and 14 columns.

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %% [markdown]
# ### Observation :-
# * There is no object datatype in the dataset.
# * There are 3 columns having int datatype and 11 columns having float datatype.

# %% [markdown]
# ### Identifying Missing Value :
# * df.isnull() - It returns True if values are missing and False if value is not missing.
# * sum() - Return the sum of the values for the requested axis.

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ### Observation :
# * There is no missing value in this dataset.

# %% [markdown]
# ### Summary Statistics :

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# crim     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# zn       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# indus    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# chas     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# nox      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# rm       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# age      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# dis      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# rad      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# tax      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# ptratio  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# black    506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# lstat    506.0   12.653063    7.141062    1.73000    6.950000   11.36000
# medv     506.0   22.532806    9.197104    5.00000   17.025000   21.20000
#
#                 75%       max
# crim       3.677082   88.9762
# zn        12.500000  100.0000
# indus     18.100000   27.7400
# chas       0.000000    1.0000
# nox        0.624000    0.8710
# rm         6.623500    8.7800
# age       94.075000  100.0000
# dis        5.188425   12.1265
# rad       24.000000   24.0000
# tax      666.000000  711.0000
# ptratio   20.200000   22.0000
# black    396.225000  396.9000
# lstat     16.955000   37.9700
# medv      25.000000   50.0000

# %% [markdown]
# ### Observation :-
# * In this dataset all the variables are numeric.
# * We can see the Columns like 'crim', 'indus', 'chas', 'rm', 'dis', 'tax' and 'lstat' are good for data exploration.

# %% [markdown]
# ## 3. Exploratory Data Analysis :

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,5))
sb.distplot(df['medv'], bins=30)
plt.show()

# %% [markdown]
# ### Observation :
# * We can say that by visualizing the target variable ('medv'), the values of 'medv' are distributed normally with few outliers.

# %%
sb.pairplot(df[['crim', 'indus', 'chas', 'rm', 'dis', 'tax','lstat']])
plt.show()

# %% [markdown]
# ### Observation :-
# * 'rm' and 'medv' have the shape like that in a normally distributed graph.
# * 'lstat' is skewed to the right.
# * 'tax' has a large amount of distribution around the point 700.

# %% [markdown]
# ## - Heatmap :
# * The correlation coefficient ranges from -1 to 1. If the value is close to 1, it means that there is a strong positive correlation between the two variables. When it is close to -1, the variables have a strong negative correlation.
#
# * We will select those features which have a high correlation with our target variable 'medv'.

# %%
t1 = df[['crim', 'indus', 'chas', 'rm', 'dis', 'tax','lstat','medv']].corr()
plt.figure(figsize=(15,10))
ax = sb.heatmap(t1,annot=True, linewidths=.5,cmap="YlGnBu")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %% [markdown]
# ### Observation :
# * From the correlation matrix we can see that 'rm' has a strong positive correlation with 'medv' (0.7), where as 'lstat' has a high negative correlation with 'medv' (-0.74).
# * The features 'rad', 'tax' pairs are strongly correlated to each other. So, we will not select these both feature.
# * And We will not select 'chas' and 'rad' because they are not continous.
# * We will not select the features 'crim' because it have lot of outliers.
# * Based on the above observations we will take 'rm', 'lstat' and 'ptratio' as our features.
# * And also based on above visualization, we will do the further analysis.

# %%
sb.set(style='darkgrid')
sb.lmplot(x = 'medv',y='rm',data=df)
plt.show()

# %% [markdown]
# ### Observation :
# * The prices increase as the value of 'rm' increases linearly.
# * There are few outliers.

# %%
sb.set(style='darkgrid')
sb.lmplot(x = 'medv',y='lstat',data=df)
plt.show()

# %% [markdown]
# ### Observation :
# * The prices tend to decrease with an increase in 'lstat'. Though it doesn’t look to be following exactly a linear line.

# %% [markdown]
# # 4. Data Modeling :

# %% [markdown]
# ##  - Data Splitting :-
# * Now we use the train_test_split function from sklearn library to split our dataset.

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['rm','lstat','ptratio']]
y = df['medv']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33,random_state=10)

# %% [markdown]
# * Here we are taking 67% of data for training and 33% data for testing.
# * Random State just fix the randomness data state which will not change.

# %% [markdown]
# ## - Training and testing the model:-
# * Now we use scikit-learn’s LinearRegression algorithm to train our model on both the training and test sets.

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# * Above it fits the model based on x_train and y_train.

# %%
y_score = lm.score(x_test,y_test)
print(y_score)
# Out:
# 0.6955765288774867

# %% [markdown]
# ## - Prediction :-
# * Now we try to predict it to the x_test.
# * And the prediction values which will be stored into y_predict.

# %%
y_predict = lm.predict(x_test)

# %% [markdown]
# ## - Model evaluation :-
# * We will evaluate our model using RMSE and R2-score.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

# %%
mae = mean_absolute_error(y_test,y_predict)
rmse = (np.sqrt(mean_squared_error(y_test,y_predict)))
# rmse1 = mean_squared_error(y_test,y_predict)
score = r2_score(y_test,y_predict)
print('Mean absolute error is {}'.format(mae))
# print(rmse1)
print('Root Mean Square Error is {}'.format(rmse))
print('R^2 score is {}'.format(score))
# Out:
# Mean absolute error is 3.7331041584167886
# Root Mean Square Error is 5.394757556652178
# R^2 score is 0.6955765288774867

# %% [markdown]
# ### Observation :-
# * With an r-squared value of .65, the model is not terrible but it’s not perfect.

# %%
plt.figure(figsize=(15,8))
plt.scatter(y_test, y_predict)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted prices")
plt.title("Actual Prices vs Predicted prices")
plt.show()

# %% [markdown]
# ### Observation :-
# * The closer we can get the points to be at the 0 line, the more accurate the model is at predicting the prices.
# * Ideally, the scatter plot should create a linear line. Since the model does not fit 100%, the scatter plot is not creating a linear line.

# %%
residual = y_test - y_predict
plt.figure(figsize=(15,5))
sb.distplot(residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=10)
plt.title('Residual counts',fontsize=20)
plt.xlabel('Residual',fontsize=10)
plt.ylabel('Count',fontsize=10)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.scatter(y_predict, residual, color ='teal')
plt.tick_params(axis='both', which='major', labelsize=10)
plt.xlabel('Predicted',fontsize=10)
plt.ylabel('Residual',fontsize=10)
plt.axhline(y=0)
plt.title('Residual vs. Predicted',fontsize=20)
plt.show()

# %% [markdown]
# # Conclusion :
# *In this project we went over the Boston house dataset in extensive detail. Learning from other people’s work and posts, I learned that although their steps were basically the same, they included and excluded different aspects of linear regression such as checking assumptions, visualizing residuals, provide some type of explanation for the results. I enjoyed working on this linear regression project, a fundamental part of machine learning.*
